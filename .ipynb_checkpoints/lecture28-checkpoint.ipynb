# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import sparse
from scipy.sparse import linalg as spla
import spectral

# %% [markdown]
# ## Eigenvalue Problems

# %%
N = 256
x_basis = spectral.Chebyshev(N)
x = x_basis.grid()
domain = spectral.Domain([x_basis])

# %%
C = x_basis.convert_TU()
D = x_basis.derivative_TU()
Z = sparse.csr_matrix((N, N))

# %%
M = sparse.csr_matrix((2*N+2, 2*N+2))
M[N:2*N, :N] = C

L = sparse.bmat([[D, -C],
                 [Z,  D]])

i = np.arange(N)
BC_rows = np.zeros((2, 2*N))
BC_rows[0, :N] = (-1)**i
BC_rows[1, :N] = (+1)**i

cols = np.zeros((2*N, 2))
cols[  N-1, 0] = 1
cols[2*N-1, 1] = 1

corner = np.zeros((2, 2))

L = sparse.bmat([[L, cols],
                 [BC_rows, corner]])
# Out:
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/_index.py:116: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %% [markdown]
# Let's do a dense solve to get all the eigenvalues of this problem.

# %%
# :(
L = L.A
M = M.A

# %%
values, vectors = scipy.linalg.eig(-L, M)

finite = np.isfinite(values)
values = values[finite]
vectors = vectors[:, finite]

order = np.argsort(values.real)
values = values[order]
vectors = vectors[:, order]

om = np.sqrt(values)

# %%
i = np.arange(len(om))+1
plt.figure()
plt.scatter(i, om)
plt.scatter(i, np.pi/2*i, marker='x')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/matplotlib/collections.py:206: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)

# %%
error = np.abs(om - np.pi/2*i)
plt.figure()
plt.plot(error)
plt.yscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Rule of thumb:
#  - about half eigenvalues will be accurate (well-resolved)
#  - other half will be unaccurate

# %%
def wave_evp(N):
    x_basis = spectral.Chebyshev(N)
    x = x_basis.grid()
    domain = spectral.Domain([x_basis])
    
    C = x_basis.convert_TU()
    D = x_basis.derivative_TU()
    Z = sparse.csr_matrix((N, N))
    
    M = sparse.csr_matrix((2*N+2, 2*N+2))
    M[N:2*N, :N] = C

    L = sparse.bmat([[D, -C],
                     [Z,  D]])

    i = np.arange(N)
    BC_rows = np.zeros((2, 2*N))
    BC_rows[0, :N] = (-1)**i
    BC_rows[1, :N] = (+1)**i

    cols = np.zeros((2*N, 2))
    cols[  N-1, 0] = 1
    cols[2*N-1, 1] = 1

    corner = np.zeros((2, 2))

    L = sparse.bmat([[L, cols],
                     [BC_rows, corner]])
    
    # :(
    L = L.A
    M = M.A
    
    values, vectors = scipy.linalg.eig(-L, M)

    finite = np.isfinite(values)
    values = values[finite]
    vectors = vectors[:, finite]

    order = np.argsort(values.real)
    values = values[order]
    vectors = vectors[:, order]

    om = np.sqrt(values)
    
    return om

# %%
om_256 = wave_evp(256)
om_512 = wave_evp(512)

# %%
plt.figure()
i = np.arange(len(om_256))
plt.scatter(i, om_256)
i = np.arange(len(om_512))
plt.scatter(i, om_512, marker='x')
i = np.arange(len(good_om))
plt.scatter(i, good_om, marker='*')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/matplotlib/collections.py:206: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)

# %%
good_om = []
for om in om_256:
    if np.min(np.abs(om - om_512)) < 1e-6:
        good_om.append(om)

# %%
len(good_om)
# Out:
# 146

# %%
np.min(np.abs(om - om_512))
# Out:
# 2.842170943040401e-14

# %%
np.array(good_om)/(np.pi/2)
# Out:
# array([  1.        +0.j,   2.        +0.j,   3.        +0.j,
#          4.        +0.j,   5.        +0.j,   6.        +0.j,
#          7.        +0.j,   8.        +0.j,   9.        +0.j,
#         10.        +0.j,  11.        +0.j,  12.        +0.j,
#         13.        +0.j,  14.        +0.j,  15.        +0.j,
#         16.        +0.j,  17.        +0.j,  18.        +0.j,
#         19.        +0.j,  20.        +0.j,  21.        +0.j,
#         22.        +0.j,  23.        +0.j,  24.        +0.j,
#         25.        +0.j,  26.        +0.j,  27.        +0.j,
#         28.        +0.j,  29.        +0.j,  30.        +0.j,
#         31.        +0.j,  32.        +0.j,  33.        +0.j,
#         34.        +0.j,  35.        +0.j,  36.        +0.j,
#         37.        +0.j,  38.        +0.j,  39.        +0.j,
#         40.        +0.j,  41.        +0.j,  42.        +0.j,
#         43.        +0.j,  44.        +0.j,  45.        +0.j,
#         46.        +0.j,  47.        +0.j,  48.        +0.j,
#         49.        +0.j,  50.        +0.j,  51.        +0.j,
#         52.        +0.j,  53.        +0.j,  54.        +0.j,
#         55.        +0.j,  56.        +0.j,  57.        +0.j,
#         58.        +0.j,  59.        +0.j,  60.        +0.j,
#         61.        +0.j,  62.        +0.j,  63.        +0.j,
#         64.        +0.j,  65.        +0.j,  66.        +0.j,
#         67.        +0.j,  68.        +0.j,  69.        +0.j,
#         70.        +0.j,  71.        +0.j,  72.        +0.j,
#         73.        +0.j,  74.        +0.j,  75.        +0.j,
#         76.        +0.j,  77.        +0.j,  78.        +0.j,
#         79.        +0.j,  80.        +0.j,  81.        +0.j,
#         82.        +0.j,  83.        +0.j,  84.        +0.j,
#         85.        +0.j,  86.        +0.j,  87.        +0.j,
#         88.        +0.j,  89.        +0.j,  90.        +0.j,
#         91.        +0.j,  92.        +0.j,  93.        +0.j,
#         94.        +0.j,  95.        +0.j,  96.        +0.j,
#         97.        +0.j,  98.        +0.j,  99.        +0.j,
#        100.        +0.j, 101.        +0.j, 102.        +0.j,
#        103.        +0.j, 104.        +0.j, 105.        +0.j,
#        106.        +0.j, 107.        +0.j, 108.        +0.j,
#        109.        +0.j, 110.        +0.j, 111.        +0.j,
#        112.        +0.j, 113.        +0.j, 114.        +0.j,
#        115.        +0.j, 116.        +0.j, 117.        +0.j,
#        118.        +0.j, 119.        +0.j, 120.        +0.j,
#        121.        +0.j, 122.        +0.j, 123.        +0.j,
#        124.        +0.j, 125.        +0.j, 126.        +0.j,
#        127.        +0.j, 128.        +0.j, 129.        +0.j,
#        130.        +0.j, 131.        +0.j, 132.        +0.j,
#        133.        +0.j, 134.        +0.j, 135.        +0.j,
#        136.        +0.j, 137.        +0.j, 138.        +0.j,
#        139.00000001+0.j, 140.        +0.j, 140.99999994+0.j,
#        142.        +0.j, 143.00000037+0.j, 144.        +0.j,
#        146.00000003+0.j, 148.00000019+0.j])

# %% [markdown]
# ## Sparse Eigenvalue Solves

# %%
N = 4096
x_basis = spectral.Chebyshev(N)
x = x_basis.grid()
domain = spectral.Domain([x_basis])

C = x_basis.convert_TU()
D = x_basis.derivative_TU()
Z = sparse.csr_matrix((N, N))

M = sparse.csr_matrix((2*N+2, 2*N+2))
M[N:2*N, :N] = C

L = sparse.bmat([[D, -C],
                 [Z,  D]])

i = np.arange(N)
BC_rows = np.zeros((2, 2*N))
BC_rows[0, :N] = (-1)**i
BC_rows[1, :N] = (+1)**i

cols = np.zeros((2*N, 2))
cols[  N-1, 0] = 1
cols[2*N-1, 1] = 1

corner = np.zeros((2, 2))

L = sparse.bmat([[L, cols],
                 [BC_rows, corner]])
L = -L
# Out:
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/_index.py:116: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray_sparse(i, j, x)

# %% [markdown]
# We need to make a linear operator that calculates $(L-\sigma^2M)^{-1}.M$.

# %%
sigma = (3*np.pi/2) + 0.01

L_si = L - sigma**2 * M
solver = spla.splu(L_si)
def matvec(X):
    return solver.solve(M @ X)
# Out:
# /opt/miniconda3/envs/dedalus_new/lib/python3.8/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:318: SparseEfficiencyWarning: splu requires CSC matrix format
#   warn('splu requires CSC matrix format', SparseEfficiencyWarning)

# %%
LO = spla.LinearOperator(dtype=L.dtype, shape=L.shape, matvec=matvec)

# %%
LO
# Out:
# <8194x8194 _CustomLinearOperator with dtype=float64>

# %%
evals, evecs = spla.eigs(LO, k=1, which='LM')

# %%
evals
# Out:
# array([-10.59908356+0.j])

# %%
np.sqrt(sigma**2 + 1/evals) - 3*np.pi/2
# Out:
# array([0.+0.j])

# %%
3*np.pi/2
# Out:
# 4.71238898038469

# %%
sigma
# Out:
# 4.7223889803846895
